# %%
import pandas as pd
import winnamax
import betclic
import netbet
import pmu
import zebet
from difflib import SequenceMatcher
import numpy as np

def similar(a,b):
    res = []
    for i in range(len(b)) :
        res.append(SequenceMatcher(None,a,b[i]).ratio())
    return np.argmax(res)

competition = {'sport': 'football', 'competition': 'ligue1'}

win = winnamax.into_a_pd(competition)
net= netbet.into_a_pd(competition)
pm = pmu.into_a_pd(competition)
zeb = zebet.into_a_pd(competition)
bet = betclic.into_a_pd(competition)

# %%
net
# Out:
#           team1        team2  odd of team 1 winning  odds of equality   \
# 0       Lorient  Montpellier                  20.00               5.00
# 1         Reims       Rennes                   3.40               3.25
# 2     Marseille     Toulouse                   1.35               4.90
# 3          Nice         Lens                   2.92               2.95
# 4        Monaco        Brest                   1.40               4.70
# 5      Toulouse    ACAjaccio                   1.97               3.20
# 6        Angers      Lorient                   2.72               3.15
# 7      FCNantes      Auxerre                   1.85               3.20
# 8          Lyon     Clermont                   1.34               4.80
# 9          Lens          PSG                   3.10               3.45
# 10   Strasbourg       Troyes                   1.68               3.70
# 11        Lille        Reims                   1.55               3.90
# 12  Montpellier    Marseille                   3.95               3.70
# 13       Rennes         Nice                   1.68               3.75
#
#     odd of team 2 winning                    key
# 0                    1.09    LorientvMontpellier
# 1                    2.00           ReimsvRennes
# 2                    6.75     MarseillevToulouse
# 3                    2.42              NicevLens
# 4                    5.90           MonacovBrest
# 5                    3.60     ToulousevACAjaccio
# 6                    2.42         AngersvLorient
# 7                    4.00       FCNantesvAuxerre
# 8                    7.00          LyonvClermont
# 9                    2.05               LensvPSG
# 10                   4.30      StrasbourgvTroyes
# 11                   5.10            LillevReims
# 12                   1.73  MontpelliervMarseille
# 13                   4.20            RennesvNice

# %%
win
# Out:
#           team1        team2  odd of team 1 winning  odds of equality   \
# 0     Marseille     Toulouse                   1.40               4.80
# 1       Lorient  Montpellier                  12.50               5.90
# 2          Nice         Lens                   3.00               3.00
# 3         Reims       Rennes                   3.55               3.35
# 4        Monaco        Brest                   1.47               4.80
# 5        Angers      Lorient                   2.90               3.30
# 6        Nantes      Auxerre                   1.94               3.40
# 7         Lille        Reims                   1.62               4.10
# 8   Montpellier    Marseille                   4.30               3.95
# 9          Lyon     Clermont                   1.40               5.20
# 10         Lens      ParisSG                   3.20               3.50
# 11   Strasbourg       Troyes                   1.80               3.85
# 12       Rennes         Nice                   1.80               3.90
# 13     Toulouse    ACAjaccio                   2.00               3.25
# 14    ACAjaccio        Reims                   3.00               3.35
# 15      Auxerre     Toulouse                   2.80               3.50
# 16     Clermont       Rennes                   4.20               3.70
# 17      Lorient       Monaco                   3.25               3.75
# 18       Nantes         Lyon                   3.55               3.75
# 19         Nice  Montpellier                   1.82               3.75
# 20      ParisSG       Angers                   1.09              10.50
# 21   Strasbourg         Lens                   3.35               3.55
# 22        Brest        Lille                   3.55               3.60
# 23       Troyes    Marseille                   4.00               3.85
#
#     odd of team 2 winning                    key
# 0                    6.50     MarseillevToulouse
# 1                    1.13    LorientvMontpellier
# 2                    2.45              NicevLens
# 3                    2.00           ReimsvRennes
# 4                    6.00           MonacovBrest
# 5                    2.50         AngersvLorient
# 6                    4.20         NantesvAuxerre
# 7                    5.40            LillevReims
# 8                    1.78  MontpelliervMarseille
# 9                    7.25          LyonvClermont
# 10                   2.05           LensvParisSG
# 11                   4.30      StrasbourgvTroyes
# 12                   4.20            RennesvNice
# 13                   4.00     ToulousevACAjaccio
# 14                   2.35        ACAjacciovReims
# 15                   2.40       AuxerrevToulouse
# 16                   1.82        ClermontvRennes
# 17                   2.05         LorientvMonaco
# 18                   1.98            NantesvLyon
# 19                   4.20       NicevMontpellier
# 20                  21.00         ParisSGvAngers
# 21                   2.10        StrasbourgvLens
# 22                   2.00            BrestvLille
# 23                   1.82       TroyesvMarseille

# %%
bet
# Out:
#           team1        team2  odd of team 1 winning  odds of equality   \
# 0       Lorient  Montpellier                  13.50               5.75
# 1         Reims       Rennes                   3.40               3.35
# 2     Marseille     Toulouse                   1.36               4.65
# 3          Nice         Lens                   2.90               3.00
# 4        Monaco        Brest                   1.42               4.45
# 5        Nantes      Auxerre                   1.90               3.28
# 6      Toulouse      Ajaccio                   1.95               3.20
# 7        Angers      Lorient                   2.75               3.13
# 8          Lyon     Clermont                   1.36               4.63
# 9          Lens      ParisSG                   3.20               3.40
# 10   Strasbourg       Troyes                   1.73               3.63
# 11        Lille        Reims                   1.54               3.90
# 12  Montpellier    Marseille                   3.88               3.57
# 13       Rennes         Nice                   1.72               3.55
# 14      Auxerre     Toulouse                   2.54               3.15
# 15      Lorient       Monaco                   2.93               3.35
# 16   Strasbourg         Lens                   3.02               3.20
# 17         Nice  Montpellier                   1.69               3.33
# 18      ParisSG       Angers                   1.06               9.55
# 19     Clermont       Rennes                   3.77               3.30
#
#     odd of team 2 winning                    key
# 0                    1.07    LorientvMontpellier
# 1                    1.95           ReimsvRennes
# 2                    6.50     MarseillevToulouse
# 3                    2.35              NicevLens
# 4                    5.80           MonacovBrest
# 5                    3.70         NantesvAuxerre
# 6                    3.63       ToulousevAjaccio
# 7                    2.40         AngersvLorient
# 8                    6.60          LyonvClermont
# 9                    2.03           LensvParisSG
# 10                   4.08      StrasbourgvTroyes
# 11                   5.15            LillevReims
# 12                   1.72  MontpelliervMarseille
# 13                   3.87            RennesvNice
# 14                   2.23       AuxerrevToulouse
# 15                   1.92         LorientvMonaco
# 16                   1.94        StrasbourgvLens
# 17                   3.70       NicevMontpellier
# 18                  13.75         ParisSGvAngers
# 19                   1.69        ClermontvRennes

# %%
zeb
# Out:
#           team1      team2  odd of team 1 winning  odds of equality   \
# 0         Reims     Rennes                   3.45               3.35
# 1          Nice       Lens                   3.05               2.95
# 2     Marseille   Toulouse                   1.43               4.80
# 3        Angers    Lorient                   2.67               3.10
# 4        Nantes    Auxerre                   1.80               3.25
# 5        Monaco      Brest                   1.34               4.50
# 6      Toulouse  ACAjaccio                   1.85               3.15
# 7          Lyon   Clermont                   1.28               4.80
# 8          Lens    ParisSG                   3.10               3.30
# 9    Strasbourg     Troyes                   1.65               3.55
# 10        Lille      Reims                   1.48               3.80
# 11  Montpellier  Marseille                   4.00               3.60
# 12       Rennes       Nice                   1.65               3.60
#
#     odd of team 2 winning                    key
# 0                    2.10           ReimsvRennes
# 1                    2.50              NicevLens
# 2                    6.10     MarseillevToulouse
# 3                    2.27         AngersvLorient
# 4                    3.65         NantesvAuxerre
# 5                    5.90           MonacovBrest
# 6                    3.55     ToulousevACAjaccio
# 7                    6.75          LyonvClermont
# 8                    1.97           LensvParisSG
# 9                    4.00      StrasbourgvTroyes
# 10                   5.00            LillevReims
# 11                   1.65  MontpelliervMarseille
# 12                   3.95            RennesvNice

# %%
import pandas as pd
import winnamax
import betclic
import netbet
import pmu
import zebet
from difflib import SequenceMatcher
import numpy as np

def similar(a,b):
    res = []
    for i in range(len(b)) :
        res.append(SequenceMatcher(None,a,b[i]).ratio())
    return np.argmax(res)

def similar_ratio(a,b) :
    res = []
    for i in range(len(b)) :
        res.append(SequenceMatcher(None,a,b[i]).ratio())
    return max(res)

competitionn = {'sport': 'football', 'competition': 'premier-league'}
def merge_results(competition):
    matches = []
    win = winnamax.into_a_pd(competition)
    net= netbet.into_a_pd(competition)
    pm = pmu.into_a_pd(competition)
    zeb = zebet.into_a_pd(competition)
    bet = betclic.into_a_pd(competition)
    long = min([len(win),len(net),len(pm),len(zeb),len(bet)])
    for i in range(long) :
        concordance_netbet = similar(win['key'][i],net['key'])
        ratio_netbet = similar_ratio(win['key'][i],net['key'])

        conc_pmu = similar(win['key'][i],pm['key'])
        ratio_pmu = similar_ratio(win['key'][i],pm['key'])

        conc_zebet = similar(win['key'][i],zeb['key'])
        ratio_zebet = similar_ratio(win['key'][i],zeb['key'])

        conc_betclic = similar(win['key'][i],bet['key'])
        ratio_betclic = similar_ratio(win['key'][i],bet['key'])

        if (ratio_netbet < 0.8 or ratio_pmu<0.8 or ratio_zebet<0.8 or ratio_betclic < 0.8) :
            continue
    
        match = [win[i:i+1],net[concordance_netbet:concordance_netbet+1],pm[conc_pmu:conc_pmu+1],zeb[conc_zebet:conc_zebet+1],bet[conc_betclic:conc_betclic+1]]
        match = pd.concat(match)
        match['site'] = ['winnamax','netbet','pmu','zebet','betclic']
        matches.append(match)
    return matches

A = merge_results(competitionn)

# %%
A[2]
# Out:
#       team1        team2  odd of team 1 winning  odds of equality   \
# 2  Brighton  Bournemouth                   1.32                5.2
# 3  Brighton  Bournemouth                   1.26                4.9
# 4  Brighton  Bournemouth                   1.28                4.9
# 5  Brighton  Bournemouth                   1.30                5.0
# 3  Brighton  Bournemouth                   1.32                4.7
#
#    odd of team 2 winning                   key      site
# 2                   8.50  BrightonvBournemouth  winnamax
# 3                   8.50  BrightonvBournemouth    netbet
# 4                   8.50  BrightonvBournemouth       pmu
# 5                   8.25  BrightonvBournemouth     zebet
# 3                   7.60  BrightonvBournemouth   betclic

# %%
resu = []
a = A[0]['odd of team 1 winning'].values
c = A[0]['odd of team 2 winning'].values
b = A[0]['odds of equality '].values
site = A[0]['site'].values
for i in range(len(A[0])) :
    for j in range(len(A[0])) :
        for k in range(len(A[0])) :
            if i==j and i == k :
                continue
            else :
                resu.append(((a[i],b[j],c[k]),(site[i],site[j],site[k])))

resu
# Out:
# [((3.4, 3.4, 2.1), ('winnamax', 'winnamax', 'netbet')),
#  ((3.4, 3.4, 2.05), ('winnamax', 'winnamax', 'pmu')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'winnamax', 'zebet')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'winnamax', 'betclic')),
#  ((3.4, 3.35, 2.1), ('winnamax', 'netbet', 'winnamax')),
#  ((3.4, 3.35, 2.1), ('winnamax', 'netbet', 'netbet')),
#  ((3.4, 3.35, 2.05), ('winnamax', 'netbet', 'pmu')),
#  ((3.4, 3.35, 2.1), ('winnamax', 'netbet', 'zebet')),
#  ((3.4, 3.35, 2.1), ('winnamax', 'netbet', 'betclic')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'pmu', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'pmu', 'netbet')),
#  ((3.4, 3.4, 2.05), ('winnamax', 'pmu', 'pmu')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'pmu', 'zebet')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'pmu', 'betclic')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'zebet', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'zebet', 'netbet')),
#  ((3.4, 3.4, 2.05), ('winnamax', 'zebet', 'pmu')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'zebet', 'zebet')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'zebet', 'betclic')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'betclic', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'betclic', 'netbet')),
#  ((3.4, 3.4, 2.05), ('winnamax', 'betclic', 'pmu')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'betclic', 'zebet')),
#  ((3.4, 3.4, 2.1), ('winnamax', 'betclic', 'betclic')),
#  ((3.35, 3.4, 2.1), ('netbet', 'winnamax', 'winnamax')),
#  ((3.35, 3.4, 2.1), ('netbet', 'winnamax', 'netbet')),
#  ((3.35, 3.4, 2.05), ('netbet', 'winnamax', 'pmu')),
#  ((3.35, 3.4, 2.1), ('netbet', 'winnamax', 'zebet')),
#  ((3.35, 3.4, 2.1), ('netbet', 'winnamax', 'betclic')),
#  ((3.35, 3.35, 2.1), ('netbet', 'netbet', 'winnamax')),
#  ((3.35, 3.35, 2.05), ('netbet', 'netbet', 'pmu')),
#  ((3.35, 3.35, 2.1), ('netbet', 'netbet', 'zebet')),
#  ((3.35, 3.35, 2.1), ('netbet', 'netbet', 'betclic')),
#  ((3.35, 3.4, 2.1), ('netbet', 'pmu', 'winnamax')),
#  ((3.35, 3.4, 2.1), ('netbet', 'pmu', 'netbet')),
#  ((3.35, 3.4, 2.05), ('netbet', 'pmu', 'pmu')),
#  ((3.35, 3.4, 2.1), ('netbet', 'pmu', 'zebet')),
#  ((3.35, 3.4, 2.1), ('netbet', 'pmu', 'betclic')),
#  ((3.35, 3.4, 2.1), ('netbet', 'zebet', 'winnamax')),
#  ((3.35, 3.4, 2.1), ('netbet', 'zebet', 'netbet')),
#  ((3.35, 3.4, 2.05), ('netbet', 'zebet', 'pmu')),
#  ((3.35, 3.4, 2.1), ('netbet', 'zebet', 'zebet')),
#  ((3.35, 3.4, 2.1), ('netbet', 'zebet', 'betclic')),
#  ((3.35, 3.4, 2.1), ('netbet', 'betclic', 'winnamax')),
#  ((3.35, 3.4, 2.1), ('netbet', 'betclic', 'netbet')),
#  ((3.35, 3.4, 2.05), ('netbet', 'betclic', 'pmu')),
#  ((3.35, 3.4, 2.1), ('netbet', 'betclic', 'zebet')),
#  ((3.35, 3.4, 2.1), ('netbet', 'betclic', 'betclic')),
#  ((3.5, 3.4, 2.1), ('pmu', 'winnamax', 'winnamax')),
#  ((3.5, 3.4, 2.1), ('pmu', 'winnamax', 'netbet')),
#  ((3.5, 3.4, 2.05), ('pmu', 'winnamax', 'pmu')),
#  ((3.5, 3.4, 2.1), ('pmu', 'winnamax', 'zebet')),
#  ((3.5, 3.4, 2.1), ('pmu', 'winnamax', 'betclic')),
#  ((3.5, 3.35, 2.1), ('pmu', 'netbet', 'winnamax')),
#  ((3.5, 3.35, 2.1), ('pmu', 'netbet', 'netbet')),
#  ((3.5, 3.35, 2.05), ('pmu', 'netbet', 'pmu')),
#  ((3.5, 3.35, 2.1), ('pmu', 'netbet', 'zebet')),
#  ((3.5, 3.35, 2.1), ('pmu', 'netbet', 'betclic')),
#  ((3.5, 3.4, 2.1), ('pmu', 'pmu', 'winnamax')),
#  ((3.5, 3.4, 2.1), ('pmu', 'pmu', 'netbet')),
#  ((3.5, 3.4, 2.1), ('pmu', 'pmu', 'zebet')),
#  ((3.5, 3.4, 2.1), ('pmu', 'pmu', 'betclic')),
#  ((3.5, 3.4, 2.1), ('pmu', 'zebet', 'winnamax')),
#  ((3.5, 3.4, 2.1), ('pmu', 'zebet', 'netbet')),
#  ((3.5, 3.4, 2.05), ('pmu', 'zebet', 'pmu')),
#  ((3.5, 3.4, 2.1), ('pmu', 'zebet', 'zebet')),
#  ((3.5, 3.4, 2.1), ('pmu', 'zebet', 'betclic')),
#  ((3.5, 3.4, 2.1), ('pmu', 'betclic', 'winnamax')),
#  ((3.5, 3.4, 2.1), ('pmu', 'betclic', 'netbet')),
#  ((3.5, 3.4, 2.05), ('pmu', 'betclic', 'pmu')),
#  ((3.5, 3.4, 2.1), ('pmu', 'betclic', 'zebet')),
#  ((3.5, 3.4, 2.1), ('pmu', 'betclic', 'betclic')),
#  ((3.3, 3.4, 2.1), ('zebet', 'winnamax', 'winnamax')),
#  ((3.3, 3.4, 2.1), ('zebet', 'winnamax', 'netbet')),
#  ((3.3, 3.4, 2.05), ('zebet', 'winnamax', 'pmu')),
#  ((3.3, 3.4, 2.1), ('zebet', 'winnamax', 'zebet')),
#  ((3.3, 3.4, 2.1), ('zebet', 'winnamax', 'betclic')),
#  ((3.3, 3.35, 2.1), ('zebet', 'netbet', 'winnamax')),
#  ((3.3, 3.35, 2.1), ('zebet', 'netbet', 'netbet')),
#  ((3.3, 3.35, 2.05), ('zebet', 'netbet', 'pmu')),
#  ((3.3, 3.35, 2.1), ('zebet', 'netbet', 'zebet')),
#  ((3.3, 3.35, 2.1), ('zebet', 'netbet', 'betclic')),
#  ((3.3, 3.4, 2.1), ('zebet', 'pmu', 'winnamax')),
#  ((3.3, 3.4, 2.1), ('zebet', 'pmu', 'netbet')),
#  ((3.3, 3.4, 2.05), ('zebet', 'pmu', 'pmu')),
#  ((3.3, 3.4, 2.1), ('zebet', 'pmu', 'zebet')),
#  ((3.3, 3.4, 2.1), ('zebet', 'pmu', 'betclic')),
#  ((3.3, 3.4, 2.1), ('zebet', 'zebet', 'winnamax')),
#  ((3.3, 3.4, 2.1), ('zebet', 'zebet', 'netbet')),
#  ((3.3, 3.4, 2.05), ('zebet', 'zebet', 'pmu')),
#  ((3.3, 3.4, 2.1), ('zebet', 'zebet', 'betclic')),
#  ((3.3, 3.4, 2.1), ('zebet', 'betclic', 'winnamax')),
#  ((3.3, 3.4, 2.1), ('zebet', 'betclic', 'netbet')),
#  ((3.3, 3.4, 2.05), ('zebet', 'betclic', 'pmu')),
#  ((3.3, 3.4, 2.1), ('zebet', 'betclic', 'zebet')),
#  ((3.3, 3.4, 2.1), ('zebet', 'betclic', 'betclic')),
#  ((3.4, 3.4, 2.1), ('betclic', 'winnamax', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('betclic', 'winnamax', 'netbet')),
#  ((3.4, 3.4, 2.05), ('betclic', 'winnamax', 'pmu')),
#  ((3.4, 3.4, 2.1), ('betclic', 'winnamax', 'zebet')),
#  ((3.4, 3.4, 2.1), ('betclic', 'winnamax', 'betclic')),
#  ((3.4, 3.35, 2.1), ('betclic', 'netbet', 'winnamax')),
#  ((3.4, 3.35, 2.1), ('betclic', 'netbet', 'netbet')),
#  ((3.4, 3.35, 2.05), ('betclic', 'netbet', 'pmu')),
#  ((3.4, 3.35, 2.1), ('betclic', 'netbet', 'zebet')),
#  ((3.4, 3.35, 2.1), ('betclic', 'netbet', 'betclic')),
#  ((3.4, 3.4, 2.1), ('betclic', 'pmu', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('betclic', 'pmu', 'netbet')),
#  ((3.4, 3.4, 2.05), ('betclic', 'pmu', 'pmu')),
#  ((3.4, 3.4, 2.1), ('betclic', 'pmu', 'zebet')),
#  ((3.4, 3.4, 2.1), ('betclic', 'pmu', 'betclic')),
#  ((3.4, 3.4, 2.1), ('betclic', 'zebet', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('betclic', 'zebet', 'netbet')),
#  ((3.4, 3.4, 2.05), ('betclic', 'zebet', 'pmu')),
#  ((3.4, 3.4, 2.1), ('betclic', 'zebet', 'zebet')),
#  ((3.4, 3.4, 2.1), ('betclic', 'zebet', 'betclic')),
#  ((3.4, 3.4, 2.1), ('betclic', 'betclic', 'winnamax')),
#  ((3.4, 3.4, 2.1), ('betclic', 'betclic', 'netbet')),
#  ((3.4, 3.4, 2.05), ('betclic', 'betclic', 'pmu')),
#  ((3.4, 3.4, 2.1), ('betclic', 'betclic', 'zebet'))]

# %%
resu[0][1][2]
# Out:
# 'netbet'

# %%
import log 
log.log("test")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\aline\OneDrive\Bureau\arbitrage paris\ignore.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/Bureau/arbitrage%20paris/ignore.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import log
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aline/OneDrive/Bureau/arbitrage%20paris/ignore.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> log.log("test")
#
# AttributeError: module 'log' has no attribute 'log'
